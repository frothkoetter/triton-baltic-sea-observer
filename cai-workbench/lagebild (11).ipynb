# %%
# daily_situation_report_spark_with_map.py

import cml.data_v1 as cmldata
from datetime import datetime
from pyspark.sql import SparkSession, Window
from pyspark.sql.functions import col, to_timestamp, row_number, coalesce, lit, round as spark_round, sin, cos, sqrt, asin, radians

# --- Imports für die Kartenerstellung ---
# Wichtiger Hinweis: Diese Bibliotheken müssen in Ihrer Umgebung installiert sein (pip install matplotlib geopandas contextily)
import matplotlib.pyplot as plt
import geopandas as gpd
import contextily as cx
import pandas as pd
from shapely.geometry import Point

# %%
# --- 1. SPARK-VERBINDUNG HERSTELLEN ---
try:
    CONNECTION_NAME = "se-aws-edl"
    conn = cmldata.get_connection(CONNECTION_NAME)
    spark = conn.get_spark_session()
    print("Spark-Session erfolgreich erstellt.")
except Exception as e:
    print(f"Fehler beim Erstellen der Spark-Session: {e}")
    print("Erstelle eine lokale Spark-Session als Fallback.")
    spark = SparkSession.builder.appName("DailyReportFallback").getOrCreate()
# Out:
# Spark Application Id:spark-4a34720e29cb4ec08cbd00d28992f52a
# Spark-Session erfolgreich erstellt.

# %%
def get_latest_ship_data(spark_session: SparkSession, db_name: str = "defense"):
    """
    Frägt die letzte bekannte Position für jedes Schiff aus marine_vessel_status ab.
    """
    table_name = f"{db_name}.marine_vessel_status"
    print(f"Lese neueste Daten aus Tabelle: {table_name}")
    try:
        all_ships_df = spark_session.read.table(table_name)
        # Fensterfunktion, um nur den neuesten Status pro Schiff zu erhalten
        window_spec = Window.partitionBy("MMSI").orderBy(col("Event_Timestamp").desc())
        latest_ships_df = all_ships_df.withColumn("row_num", row_number().over(window_spec)) \
                                      .filter(col("row_num") == 1).drop("row_num")
        return latest_ships_df
    except Exception as e:
        print(f"Fehler bei der Abfrage von {table_name}: {e}")
        return None

def get_sanctioned_vessels(spark_session: SparkSession, db_name: str = "defense"):
    """Lädt die Liste der sanktionierten Schiffe."""
    table_name = f"{db_name}.sanctioned_vessels"
    print(f"Lese Daten aus Tabelle: {table_name}")
    return spark_session.sql(f"SELECT MMSI, Name, Sanction_Reason FROM {table_name} WHERE MMSI IS NOT NULL")

def get_latest_buoy_data(spark_session: SparkSession, db_name: str = "defense"):
    """Frägt die neuesten Bojen-Detektionsdaten ab."""
    table_name = f"{db_name}.buoy_data"
    print(f"Lese Daten aus Tabelle: {table_name}")
    try:
        df = spark_session.read.table(table_name)
        result_row_list = df.selectExpr("max(to_date(ts)) as max_date").collect()
        
        # Korrigierte Zeile: Greife auf das erste Element der Liste und dann auf den Feldnamen zu
        if not result_row_list or result_row_list[0]['max_date'] is None:
            return spark_session.createDataFrame([], df.schema)
        
        latest_date = result_row_list[0]['max_date']
        return df.withColumn("event_date", to_timestamp(col("ts"))).filter(f"to_date(event_date) = '{latest_date}'")
    except Exception as e:
        print(f"Fehler bei der Abfrage von {table_name}: {e}")
        return None


def get_latest_social_media_data(spark_session: SparkSession, db_name: str = "defense"):
    """Frägt die neuesten Social-Media-Daten ab."""
    table_name = f"{db_name}.social_media_messages"
    print(f"Lese Daten aus Tabelle: {table_name}")
    try:
        df = spark_session.read.table(table_name)
        result_row_list = df.selectExpr("max(to_date(ts)) as max_date").collect()
        
        # Corrected line
        if not result_row_list or result_row_list[0]['max_date'] is None:
            return spark_session.createDataFrame([], df.schema)
        
        latest_date = result_row_list[0]['max_date']
        return df.withColumn("event_date", to_timestamp(col("ts"))).filter(f"to_date(event_date) = '{latest_date}' AND priority IN ('hoch', 'mittel')")
    except Exception as e:
        print(f"Fehler bei der Abfrage von {table_name}: {e}")
        return None


def get_area_violations(spark_session: SparkSession, db_name: str = "defense"):
    """Frägt die View 'area_violation' ab."""
    view_name = f"{db_name}.area_violation"
    print(f"Frage View ab: {view_name}")
    try:
        return spark_session.sql(f"SELECT * FROM {view_name} ORDER BY event_timestamp DESC")
    except Exception as e:
        print(f"Warnung: Konnte View {view_name} nicht abfragen. Grund: {e}")
        return None

def get_buoys_near_harbours(spark_session: SparkSession, db_name: str = "defense"):
    """Frägt die View 'buoy_near_harbours' ab."""
    view_name = f"{db_name}.buoy_near_harbours"
    print(f"Frage View ab: {view_name}")
    try:
        return spark_session.sql(f"SELECT * FROM {view_name} ORDER BY ts DESC")
    except Exception as e:
        print(f"Warnung: Konnte View {view_name} nicht abfragen. Grund: {e}")
        return None

def get_german_fleet_status(spark_session: SparkSession, latest_ship_df, db_name: str = "defense"):
    """Kombiniert die statische Flottenliste mit den neuesten dynamischen Positions- und Statusdaten."""
    fleet_table = f"{db_name}.german_navy_fleet"
    print(f"Erstelle Flottenstatus aus '{fleet_table}' und Echtzeitdaten.")
    fleet_df = spark_session.read.table(fleet_table)

    fleet_status_df = fleet_df.join(latest_ship_df, fleet_df.mmsi == latest_ship_df.mmsi, "left") \
                              .select(
                                  fleet_df.name,
                                  fleet_df['class'].alias("klasse"),
                                  coalesce(latest_ship_df.status, lit("Keine Daten")).alias("status"),
                                  latest_ship_df.latitude.alias("latitude"),
                                  latest_ship_df.longitude.alias("longitude")
                              ).orderBy("klasse", "name")
    return fleet_status_df

# %%
# --- ind_ships_near_sanctioned ANALYSEFUNKTION ---
def find_ships_near_sanctioned(spark_session: SparkSession, latest_ship_df, sanctioned_info_df, distance_km=1):
    """Findet alle Schiffe, die sich innerhalb einer bestimmten Distanz zu einem sanktionierten Schiff befinden."""
    if latest_ship_df is None or sanctioned_info_df is None:
        return None

    sanctioned_positions_df = latest_ship_df.join(
        sanctioned_info_df, latest_ship_df.mmsi == sanctioned_info_df.MMSI, "inner"
    ).select(
        latest_ship_df.mmsi.alias("sanctioned_mmsi"),
        sanctioned_info_df.Name.alias("sanctioned_name"),
        latest_ship_df.latitude.alias("sanctioned_lat"),
        latest_ship_df.longitude.alias("sanctioned_lon")
    )

    if sanctioned_positions_df.count() == 0:
        print("Keine sanktionierten Schiffe mit aktuellen Positionsdaten gefunden.")
        return None

    nearby_ships_df = latest_ship_df.crossJoin(sanctioned_positions_df) \
        .filter(latest_ship_df.mmsi != col("sanctioned_mmsi"))

    haversine_expr = (
        lit(6371 * 2) * asin(sqrt(
            sin(radians(latest_ship_df.latitude) - radians(sanctioned_positions_df.sanctioned_lat)) / 2)**2 + \
            cos(radians(latest_ship_df.latitude)) * cos(radians(sanctioned_positions_df.sanctioned_lat)) * \
            sin(radians(latest_ship_df.longitude) - radians(sanctioned_positions_df.sanctioned_lon)) / 2)**2
        )

    result_df = nearby_ships_df.withColumn("distance", haversine_expr) \
                               .filter(col("distance") <= distance_km) \
                               .select(
                                   latest_ship_df.mmsi.alias("nearby_ship_mmsi"),
                                   col("sanctioned_mmsi"),
                                   col("sanctioned_name"),
                                   spark_round(col("distance"), 3).alias("distance_km")
                               ).orderBy("sanctioned_mmsi", "nearby_ship_mmsi")
    
    return result_df

# %%
# --- 3. NEUE FUNKTION ZUR KARTENERSTELLUNG ---
def create_fleet_map(fleet_status_df, filename="flottenkarte.png"):
    """
    Erstellt eine Karte mit den Positionen der Flotte und speichert sie als Bild.
    """
    if fleet_status_df is None:
        print("Keine Flottendaten für die Kartenerstellung vorhanden.")
        return None
        
    fleet_pd = fleet_status_df.toPandas()
    fleet_pd.dropna(subset=['latitude', 'longitude'], inplace=True)
    
    if fleet_pd.empty:
        print("Keine Schiffe mit gültigen Koordinaten gefunden. Karte wird nicht erstellt.")
        return None

    geometry = [Point(xy) for xy in zip(fleet_pd['longitude'], fleet_pd['latitude'])]
    gdf = gpd.GeoDataFrame(fleet_pd, geometry=geometry, crs="EPSG:4326")
    
    fig, ax = plt.subplots(1, 1, figsize=(15, 12))
    gdf_web_mercator = gdf.to_crs(epsg=3857)
    gdf_web_mercator.plot(ax=ax, marker='o', color='red', markersize=50, edgecolor='black', zorder=2, label='Position der Marineeinheiten')
    
    for x, y, label in zip(gdf_web_mercator.geometry.x, gdf_web_mercator.geometry.y, gdf_web_mercator.name):
        ax.text(x + 5000, y, label, fontsize=9, ha='left', zorder=3)
        
    cx.add_basemap(ax, source=cx.providers.OpenStreetMap.Mapnik, zoom=6)
    
    ax.set_title(f"Positionen der Deutschen Marine (Stand: {datetime.now().strftime('%Y-%m-%d %H:%M')})", fontsize=16)
    ax.set_axis_off()
    plt.legend()
    plt.tight_layout()
    
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close(fig)
    print(f"Karte der Flottenpositionen wurde erfolgreich in '{filename}' gespeichert.")
    return filename

# %%
def create_critical_detections_map(critical_detections, filename="critical_detections_map.png"):
    """
    Erstellt eine Karte, die die Positionen der kritischen Detektionen anzeigt und speichert sie als Bild.
    """
    if not critical_detections:
        return None

    detections_data = []
    for row in critical_detections:
        try:
            lat = row['geo_position_lat']
            lon = row['geo_position_lon']
            obj_type = row['payload_object_type']
        except KeyError:
            continue

        if lat is not None and lon is not None:
            detections_data.append({
                'latitude': lat,
                'longitude': lon,
                'object_type': obj_type
            })

    if not detections_data:
        return None

    detections_pd = pd.DataFrame(detections_data)
    geometry = [Point(xy) for xy in zip(detections_pd['longitude'], detections_pd['latitude'])]
    gdf = gpd.GeoDataFrame(detections_pd, geometry=geometry, crs="EPSG:4326")

    fig, ax = plt.subplots(1, 1, figsize=(15, 12))
    gdf_web_mercator = gdf.to_crs(epsg=3857)

    unique_object_types = gdf_web_mercator['object_type'].unique()
    colors = plt.cm.get_cmap('viridis', len(unique_object_types))
    for i, obj_type in enumerate(unique_object_types):
        subset = gdf_web_mercator[gdf_web_mercator['object_type'] == obj_type]
        subset.plot(ax=ax, marker='X', markersize=200, color=colors(i), edgecolor='white', zorder=3, label=f'Typ: {obj_type.upper()}')

    cx.add_basemap(ax, source=cx.providers.OpenStreetMap.Mapnik)
    ax.set_title('Positionen kritischer Detektionen', fontsize=16)
    ax.set_axis_off()
    plt.legend()
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close(fig)

    return filename

# %%
# The main create_daily_report function
def create_daily_report(spark_session: SparkSession):
    """Führt alle Analysen durch und generiert den Textbericht sowie die Karte."""
    
    # 1. Daten abrufen
    # ...
    latest_ship_df = get_latest_ship_data(spark_session)
    if latest_ship_df is None:
        print("Kritischer Fehler: Konnte keine Schiffsdaten laden. Bericht wird abgebrochen.")
        return
    latest_ship_df.cache()

    sanctioned_df = get_sanctioned_vessels(spark_session)
    buoy_df = get_latest_buoy_data(spark_session)
    social_media_df = get_latest_social_media_data(spark_session)
    area_violations_df = get_area_violations(spark_session)
    buoys_near_harbours_df = get_buoys_near_harbours(spark_session)
    german_fleet_status_df = get_german_fleet_status(spark_session, latest_ship_df)

    # 2. Analysen durchführen
    active_ship_count = latest_ship_df.count()
    suspicious_activities = latest_ship_df.filter((col("Status").isin("Moored", "At anchor")) & (col("Speed") > 1.0)).collect()
    nearby_sanctioned_df = find_ships_near_sanctioned(spark_session, latest_ship_df, sanctioned_df)
    
    fleet_status = german_fleet_status_df.collect() if german_fleet_status_df else []
    critical_detections = buoy_df.filter(col("payload_object_type").isin("SUBMARINE", "ORDNANCE")).collect() if buoy_df else []
    relevant_tweets = social_media_df.collect() if social_media_df else []
    area_violations = area_violations_df.collect() if area_violations_df else []
    buoys_near_harbours = buoys_near_harbours_df.collect() if buoys_near_harbours_df else []
    nearby_sanctioned = nearby_sanctioned_df.collect() if nearby_sanctioned_df else []
  
    # 3. Visuelle Ausgabe (Karte)
    fleet_map_path = create_fleet_map(german_fleet_status_df)
    critical_detections_map_path = create_critical_detections_map(critical_detections)

    # 4. Text-Bericht formatieren
    report = f"""
=====================================================
            TÄGLICHES LAGEBILD (via Spark)
=====================================================
Datum: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}
Datenbank: defense
-----------------------------------------------------

1. ALLGEMEINE LAGE
-------------------
- Aktive maritime Einheiten im Datensatz: {active_ship_count}
- Kritische Unterwasser-Detektionen heute: {len(critical_detections)}
- Relevante Social-Media-Meldungen heute: {len(relevant_tweets)}

2. FLOTTENSTATUS DEUTSCHE MARINE
----------------------------------
"""
    # Embed the fleet map
    if fleet_map_path:
        report += f"![Positionen der Deutschen Marine]({fleet_map_path})\n\n"
    else:
        report += "- Flottenstatus konnte nicht ermittelt werden.\n"

    # Report text for fleet status
    if fleet_status:
        current_class = ""
        for ship in fleet_status:
            if ship['klasse'] != current_class:
                current_class = ship['klasse']
                report += f"\n--- {current_class.upper()} ---\n"
            report += f"- {ship['name']:<30} | Status: {ship['status']:<25} | Position: ({ship['latitude']}, {ship['longitude']})\n"
    else: report += "- Flottenstatus konnte nicht ermittelt werden.\n"

    report += "\n3. RISIKOANALYSE: SCHIFFE IN DER NÄHE SANKTIONIERTER EINHEITEN (< 1 km)\n-------------------------------------------------------------------------\n"
    if nearby_sanctioned:
        for row in nearby_sanctioned:
            report += (f"- Schiff MMSI {row['nearby_ship_mmsi']} ist {row['distance_km']:.3f} km entfernt von "
                       f"sanktionierter Einheit '{row['sanctioned_name']}' (MMSI {row['sanctioned_mmsi']}).\n")
    else: report += "- Keine Schiffe in unmittelbarer Nähe (< 1 km) zu bekannten sanktionierten Einheiten detektiert.\n"

    report += "\n4. MARITIME LAGE: VERDÄCHTIGE AKTIVITÄTEN\n--------------------------------------------\n"
    if suspicious_activities:
        for row in suspicious_activities:
            report += f"- Inkonsistente Bewegung: MMSI {row['mmsi']} meldet '{row['status']}', bewegt sich aber mit {row['speed']:.1f} Knoten.\n"
    else: report += "- Keine verdächtigen maritimen Aktivitäten identifiziert.\n"

    report += "\n5. ÜBERWACHUNGSGEBIETE: GEBIETSÜBERGÄNGE\n---------------------------------------------\n"
    if area_violations:
        for row in area_violations:
            report += f"- {row['event_timestamp']}: MMSI {row['mmsi']} hat Gebiet '{row['area_id']}' betreten/verlassen (Aktion: {row['transition']}).\n"
    else: report += "- Keine neuen Gebietsübergänge in den definierten Beobachtungsgebieten festgestellt.\n"

    report += "\n6. UNTERWASSERLAGE: KRITISCHE DETEKTIONEN\n-------------------------------------------\n"
    
    # Embed the critical detections map
    if critical_detections_map_path:
        report += f"![Karte kritischer Detektionen]({critical_detections_map_path})\n\n"
    
    if critical_detections:
        for row in critical_detections:
            confidence_value = "N/A"
            try:
                confidence_value = row['payload_object_confidence']
            except KeyError:
                pass
            
            report += (f"- Detektion bei ({row['geo_position_lat']:.4f}, {row['geo_position_lon']:.4f}): Typ '{row['payload_object_type']}', "
                       f"Klassifizierung '{row['payload_object_classification']}' mit {confidence_value}% Konfidenz.\n")
    else: report += "- Keine kritischen Unterwasserobjekte (U-Boote/Kampfmittel) detektiert.\n"

    report += "\n7. UNTERWASSERLAGE: DETEKTIONEN IN HAFENNÄHE\n------------------------------------------------\n"
    if buoys_near_harbours:
        for row in buoys_near_harbours:
            report += (f"- Boje {row['buoyid']} meldet Objekt '{row['payload_object_type']}' {row['distance_km']:.2f} km von Hafen {row['harbor_name']}.\n")
    else: report += "- Keine Bojen-Detektionen innerhalb von 10 km zu bekannten Häfen.\n"

    report += "\n8. SOCIAL MEDIA INTELLIGENCE (OSINT)\n--------------------------------------\n"
    if relevant_tweets:
        for row in relevant_tweets:
            report += f"- Tweet (Priorität: {row['priority'].upper()}) von @{row['user_username']}: \"{row['tweet']}\"\n"
    else: report += "- Keine Social-Media-Meldungen mit hoher oder mittlerer Priorität.\n"
        
    report += "\n==================== ENDE DES BERICHTS ====================\n"
    
    latest_ship_df.unpersist()
    return report

# %%
if __name__ == "__main__":
    print("Starte die Erstellung des täglichen Lagebilds...")
    daily_report_text = create_daily_report(spark)
    print(daily_report_text)
    spark.stop()
    print("Spark-Session beendet.")
# Out:
# Starte die Erstellung des täglichen Lagebilds...
# Lese neueste Daten aus Tabelle: defense.marine_vessel_status
# Hive Session ID = e0808921-e625-4520-8386-f38951f12b26
# Lese Daten aus Tabelle: defense.sanctioned_vessels
# Lese Daten aus Tabelle: defense.buoy_data
# Lese Daten aus Tabelle: defense.social_media_messages
# Frage View ab: defense.area_violation
# Warnung: Konnte View defense.area_violation nicht abfragen. Grund: [UNRESOLVED_ROUTINE] Cannot resolve function `ST_GeomFromText` on search path [`system`.`builtin`, `system`.`session`, `spark_catalog`.`default`].; line 4 pos 8
# Frage View ab: defense.buoy_near_harbours
# Erstelle Flottenstatus aus 'defense.german_navy_fleet' und Echtzeitdaten.
# Keine sanktionierten Schiffe mit aktuellen Positionsdaten gefunden.
# Karte der Flottenpositionen wurde erfolgreich in 'flottenkarte.png' gespeichert.
# /tmp/ipykernel_4497/2417931271.py:35: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('viridis', len(unique_object_types))
# =====================================================
#             TÄGLICHES LAGEBILD (via Spark)
# =====================================================
# Datum: 2025-09-17 21:34:34
# Datenbank: defense
# -----------------------------------------------------
#
# 1. ALLGEMEINE LAGE
# -------------------
# - Aktive maritime Einheiten im Datensatz: 50
# - Kritische Unterwasser-Detektionen heute: 299
# - Relevante Social-Media-Meldungen heute: 3
#
# 2. FLOTTENSTATUS DEUTSCHE MARINE
# ----------------------------------
# ![Positionen der Deutschen Marine](flottenkarte.png)
#
#
# --- FLOTTENDIENSTBOOTE ---
# - A50 Oker                       | Status: Moored                    | Position: (54.41481, 18.08236)
# - A52 Oste                       | Status: Moored                    | Position: (54.19982, 12.1676)
# - A53 Alster                     | Status: Moored                    | Position: (56.08067, 16.56429)
#
# --- FREGATTEN ---
# - FGS Baden-Württemberg          | Status: Moored                    | Position: (53.89909, 12.82041)
# - FGS Bayern                     | Status: Moored                    | Position: (56.75677, 19.79897)
# - FGS Brandenburg                | Status: Moored                    | Position: (54.47336, 16.88668)
# - FGS Hamburg                    | Status: Moored                    | Position: (58.80881, 22.99572)
# - FGS Hessen                     | Status: Moored                    | Position: (56.43143, 20.84243)
# - FGS Mecklenburg-Vorpommern     | Status: Moored                    | Position: (55.06649, 17.54902)
# - FGS Nordrhein-Westfalen        | Status: Moored                    | Position: (54.17448, 12.30514)
# - FGS Rheinland-Pfalz            | Status: Moored                    | Position: (54.16563, 11.91079)
# - FGS Sachsen                    | Status: Moored                    | Position: (59.00536, 23.5418)
# - FGS Sachsen-Anhalt             | Status: Moored                    | Position: (54.7759, 17.93127)
# - FGS Schleswig-Holstein         | Status: Moored                    | Position: (55.81056, 15.30706)
#
# --- KORVETTEN ---
# - FGS Braunschweig               | Status: Moored                    | Position: (56.49882, 23.15793)
# - FGS Erfurt                     | Status: Moored                    | Position: (54.5403, 14.78729)
# - FGS Ludwigshafen am Rhein      | Status: Moored                    | Position: (53.88455, 12.22693)
# - FGS Magdeburg                  | Status: Moored                    | Position: (54.49349, 17.43848)
# - FGS Oldenburg                  | Status: Moored                    | Position: (54.84432, 14.34287)
#
# --- MINENABWEHREINHEITEN ---
# - FGS Auerbach/Oberpfalz         | Status: Moored                    | Position: (56.3241, 19.89342)
# - FGS Dillingen                  | Status: Moored                    | Position: (54.02155, 12.57601)
# - FGS Ensdorf                    | Status: Moored                    | Position: (60.2972, 23.72812)
# - FGS Fulda                      | Status: Moored                    | Position: (58.81615, 23.12071)
# - FGS Homburg                    | Status: Moored                    | Position: (56.71741, 23.11851)
# - FGS Kühlungsborn               | Status: Moored                    | Position: (54.59716, 13.66949)
# - FGS Passau                     | Status: Moored                    | Position: (54.60801, 14.69842)
# - FGS Pegnitz                    | Status: Moored                    | Position: (56.48884, 20.61053)
# - FGS Siegburg                   | Status: Moored                    | Position: (54.14568, 12.27804)
# - FGS Sulzbach-Rosenberg         | Status: Moored                    | Position: (59.29256, 20.59154)
# - FGS Weiden                     | Status: Moored                    | Position: (56.84384, 23.47519)
# - FGS Weilheim                   | Status: Moored                    | Position: (55.35278, 19.23598)
#
# --- SONSTIGE ---
# - FGS Baltrum                    | Status: Keine Daten               | Position: (None, None)
# - FGS Borkum                     | Status: Keine Daten               | Position: (None, None)
# - FGS Gorch Fock                 | Status: Moored                    | Position: (55.17105, 19.17462)
# - FGS Juist                      | Status: Keine Daten               | Position: (None, None)
# - FGS Langeoog                   | Status: Keine Daten               | Position: (None, None)
# - FGS Norderney                  | Status: Keine Daten               | Position: (None, None)
# - FGS Planet                     | Status: Moored                    | Position: (54.25501, 14.87812)
# - FGS Wangerooge                 | Status: Keine Daten               | Position: (None, None)
#
# --- U-BOOTE ---
# - U-31                           | Status: Moored                    | Position: (54.44854, 13.03061)
# - U-32                           | Status: Moored                    | Position: (59.39862, 18.38508)
# - U-33                           | Status: Moored                    | Position: (55.61378, 16.5127)
# - U-34                           | Status: Moored                    | Position: (54.54688, 13.93919)
# - U-35                           | Status: Moored                    | Position: (54.40305, 13.99561)
# - U-36                           | Status: Moored                    | Position: (59.56397, 19.86752)
#
# --- VERSORGUNGSSCHIFFE/TENDER ---
# - A1411 Berlin                   | Status: Moored                    | Position: (59.77511, 24.13764)
# - A1412 Frankfurt am Main        | Status: Moored                    | Position: (54.45289, 18.23933)
# - A1413 Bonn                     | Status: Moored                    | Position: (54.37223, 17.15364)
# - A1442 Spessart                 | Status: Moored                    | Position: (56.18803, 20.1895)
# - A1443 Rhön                     | Status: Moored                    | Position: (56.65178, 22.02268)
# - A511 Elbe                      | Status: Moored                    | Position: (58.5693, 24.50797)
# - A512 Mosel                     | Status: Moored                    | Position: (54.29588, 15.68273)
# - A513 Rhein                     | Status: Moored                    | Position: (54.03575, 12.08027)
# - A514 Werra                     | Status: Moored                    | Position: (57.1701, 21.01105)
# - A515 Main                      | Status: Moored                    | Position: (55.04366, 14.77199)
# - A516 Donau                     | Status: Moored                    | Position: (54.85563, 17.2499)
#
# 3. RISIKOANALYSE: SCHIFFE IN DER NÄHE SANKTIONIERTER EINHEITEN (< 1 km)
# -------------------------------------------------------------------------
# - Keine Schiffe in unmittelbarer Nähe (< 1 km) zu bekannten sanktionierten Einheiten detektiert.
#
# 4. MARITIME LAGE: VERDÄCHTIGE AKTIVITÄTEN
# --------------------------------------------
# - Inkonsistente Bewegung: MMSI MAR123421 meldet 'Moored', bewegt sich aber mit 2.0 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123431 meldet 'Moored', bewegt sich aber mit 2.4 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123420 meldet 'Moored', bewegt sich aber mit 2.4 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123424 meldet 'Moored', bewegt sich aber mit 4.6 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123449 meldet 'Moored', bewegt sich aber mit 2.0 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123416 meldet 'Moored', bewegt sich aber mit 1.4 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123427 meldet 'Moored', bewegt sich aber mit 1.9 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123437 meldet 'Moored', bewegt sich aber mit 1.6 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123444 meldet 'Moored', bewegt sich aber mit 3.4 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123446 meldet 'Moored', bewegt sich aber mit 1.5 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123426 meldet 'Moored', bewegt sich aber mit 2.9 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123442 meldet 'Moored', bewegt sich aber mit 2.0 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123423 meldet 'Moored', bewegt sich aber mit 2.4 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123422 meldet 'Moored', bewegt sich aber mit 3.9 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123443 meldet 'Moored', bewegt sich aber mit 1.3 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123418 meldet 'Moored', bewegt sich aber mit 4.1 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123436 meldet 'Moored', bewegt sich aber mit 1.3 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123410 meldet 'Moored', bewegt sich aber mit 1.8 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123440 meldet 'Moored', bewegt sich aber mit 1.8 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123419 meldet 'Moored', bewegt sich aber mit 1.4 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123447 meldet 'Moored', bewegt sich aber mit 2.9 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123429 meldet 'Moored', bewegt sich aber mit 3.3 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123401 meldet 'Moored', bewegt sich aber mit 3.0 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123439 meldet 'Moored', bewegt sich aber mit 4.1 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123441 meldet 'Moored', bewegt sich aber mit 3.3 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123414 meldet 'Moored', bewegt sich aber mit 2.5 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123434 meldet 'Moored', bewegt sich aber mit 3.3 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123402 meldet 'Moored', bewegt sich aber mit 3.8 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123433 meldet 'Moored', bewegt sich aber mit 2.8 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123407 meldet 'Moored', bewegt sich aber mit 3.3 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123435 meldet 'Moored', bewegt sich aber mit 1.6 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123432 meldet 'Moored', bewegt sich aber mit 3.2 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123409 meldet 'Moored', bewegt sich aber mit 1.2 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123413 meldet 'Moored', bewegt sich aber mit 1.4 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123428 meldet 'Moored', bewegt sich aber mit 1.2 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123438 meldet 'Moored', bewegt sich aber mit 1.7 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123400 meldet 'Moored', bewegt sich aber mit 4.7 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123425 meldet 'Moored', bewegt sich aber mit 2.1 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123405 meldet 'Moored', bewegt sich aber mit 2.4 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123404 meldet 'Moored', bewegt sich aber mit 2.1 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123445 meldet 'Moored', bewegt sich aber mit 1.6 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123406 meldet 'Moored', bewegt sich aber mit 1.9 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123403 meldet 'Moored', bewegt sich aber mit 1.8 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123412 meldet 'Moored', bewegt sich aber mit 1.3 Knoten.
# - Inkonsistente Bewegung: MMSI MAR123417 meldet 'Moored', bewegt sich aber mit 1.2 Knoten.
#
# 5. ÜBERWACHUNGSGEBIETE: GEBIETSÜBERGÄNGE
# ---------------------------------------------
# - Keine neuen Gebietsübergänge in den definierten Beobachtungsgebieten festgestellt.
#
# 6. UNTERWASSERLAGE: KRITISCHE DETEKTIONEN
# -------------------------------------------
# ![Karte kritischer Detektionen](critical_detections_map.png)
#
# - Detektion bei (55.0265, 14.7048): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 60% Konfidenz.
# - Detektion bei (54.5008, 13.6904): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 64% Konfidenz.
# - Detektion bei (54.4621, 13.7338): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 37% Konfidenz.
# - Detektion bei (53.9275, 11.4065): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 87% Konfidenz.
# - Detektion bei (55.1367, 14.7148): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (55.7233, 21.1422): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 62% Konfidenz.
# - Detektion bei (54.0434, 12.1466): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 98% Konfidenz.
# - Detektion bei (59.3742, 24.7673): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 85% Konfidenz.
# - Detektion bei (56.5632, 20.9877): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (56.9999, 24.1746): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 77% Konfidenz.
# - Detektion bei (60.1567, 25.0214): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 63% Konfidenz.
# - Detektion bei (59.3656, 24.0683): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 93% Konfidenz.
# - Detektion bei (54.4877, 18.5583): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 88% Konfidenz.
# - Detektion bei (60.4801, 22.2967): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 58% Konfidenz.
# - Detektion bei (55.1233, 14.7487): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 54% Konfidenz.
# - Detektion bei (59.3195, 24.0996): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 33% Konfidenz.
# - Detektion bei (53.9708, 14.1806): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 94% Konfidenz.
# - Detektion bei (54.3254, 10.2073): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 96% Konfidenz.
# - Detektion bei (55.0889, 14.7188): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 81% Konfidenz.
# - Detektion bei (54.2904, 18.6892): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 69% Konfidenz.
# - Detektion bei (56.9069, 24.1262): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 50% Konfidenz.
# - Detektion bei (59.3159, 18.0760): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 75% Konfidenz.
# - Detektion bei (59.4768, 24.6995): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 84% Konfidenz.
# - Detektion bei (56.4763, 21.0419): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 85% Konfidenz.
# - Detektion bei (54.3430, 13.1557): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 61% Konfidenz.
# - Detektion bei (54.0997, 12.0571): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 89% Konfidenz.
# - Detektion bei (57.0054, 24.1588): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 56% Konfidenz.
# - Detektion bei (57.4823, 21.6051): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (56.1319, 15.4975): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 60% Konfidenz.
# - Detektion bei (57.0290, 24.1617): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 51% Konfidenz.
# - Detektion bei (54.5547, 13.6849): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 86% Konfidenz.
# - Detektion bei (54.4810, 16.8841): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 85% Konfidenz.
# - Detektion bei (55.0803, 14.8015): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 37% Konfidenz.
# - Detektion bei (55.7701, 21.0917): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 62% Konfidenz.
# - Detektion bei (54.5803, 16.7726): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 89% Konfidenz.
# - Detektion bei (56.8876, 24.0175): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 53% Konfidenz.
# - Detektion bei (54.3921, 10.1501): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (54.4691, 13.6134): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 79% Konfidenz.
# - Detektion bei (59.2420, 18.0380): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 61% Konfidenz.
# - Detektion bei (60.4505, 22.2510): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 52% Konfidenz.
# - Detektion bei (56.8894, 24.1452): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 89% Konfidenz.
# - Detektion bei (55.1526, 14.6233): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 85% Konfidenz.
# - Detektion bei (56.6034, 20.9490): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (55.1290, 14.7542): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 76% Konfidenz.
# - Detektion bei (54.1136, 12.0899): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 88% Konfidenz.
# - Detektion bei (54.5657, 16.7834): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 86% Konfidenz.
# - Detektion bei (56.0830, 15.5940): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 98% Konfidenz.
# - Detektion bei (60.3916, 22.2861): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (54.2371, 10.1487): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 96% Konfidenz.
# - Detektion bei (57.3830, 21.6359): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 59% Konfidenz.
# - Detektion bei (57.3679, 21.4944): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 54% Konfidenz.
# - Detektion bei (59.2619, 24.0736): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 82% Konfidenz.
# - Detektion bei (54.5382, 16.9308): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 60% Konfidenz.
# - Detektion bei (60.2400, 24.8559): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 96% Konfidenz.
# - Detektion bei (59.2662, 18.1181): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 59% Konfidenz.
# - Detektion bei (57.3796, 21.5319): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 54% Konfidenz.
# - Detektion bei (60.3565, 22.3304): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 97% Konfidenz.
# - Detektion bei (59.3200, 18.1602): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 84% Konfidenz.
# - Detektion bei (56.1627, 15.5307): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 56% Konfidenz.
# - Detektion bei (54.4143, 10.1553): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 52% Konfidenz.
# - Detektion bei (57.4166, 21.5921): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (57.3865, 21.5114): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (59.3351, 18.0676): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (54.3548, 13.1050): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 67% Konfidenz.
# - Detektion bei (54.5127, 18.5156): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 86% Konfidenz.
# - Detektion bei (56.2337, 15.5500): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 99% Konfidenz.
# - Detektion bei (59.2932, 24.1525): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 51% Konfidenz.
# - Detektion bei (60.3634, 22.2140): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 91% Konfidenz.
# - Detektion bei (54.5701, 18.4381): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (59.2633, 24.0140): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 42% Konfidenz.
# - Detektion bei (54.1764, 12.1373): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 88% Konfidenz.
# - Detektion bei (59.3841, 18.0154): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 45% Konfidenz.
# - Detektion bei (60.5116, 22.2558): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 86% Konfidenz.
# - Detektion bei (55.7238, 21.1365): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 60% Konfidenz.
# - Detektion bei (53.8763, 14.2140): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 89% Konfidenz.
# - Detektion bei (57.2937, 21.5653): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 88% Konfidenz.
# - Detektion bei (54.5917, 13.6098): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 89% Konfidenz.
# - Detektion bei (56.0789, 15.6797): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 78% Konfidenz.
# - Detektion bei (54.0967, 12.1850): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 97% Konfidenz.
# - Detektion bei (54.5970, 13.5992): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 60% Konfidenz.
# - Detektion bei (54.4487, 18.6633): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 77% Konfidenz.
# - Detektion bei (57.3026, 21.6042): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 90% Konfidenz.
# - Detektion bei (56.5265, 21.0691): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 66% Konfidenz.
# - Detektion bei (53.8624, 11.4036): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 70% Konfidenz.
# - Detektion bei (59.4292, 17.9944): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 55% Konfidenz.
# - Detektion bei (55.1895, 14.8042): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 61% Konfidenz.
# - Detektion bei (55.6683, 21.1707): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 53% Konfidenz.
# - Detektion bei (54.0489, 12.1153): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 57% Konfidenz.
# - Detektion bei (59.3572, 24.7938): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 92% Konfidenz.
# - Detektion bei (54.3813, 10.1670): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 95% Konfidenz.
# - Detektion bei (54.1733, 12.2046): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 96% Konfidenz.
# - Detektion bei (57.4105, 21.6023): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 91% Konfidenz.
# - Detektion bei (59.3866, 18.0411): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 86% Konfidenz.
# - Detektion bei (54.4889, 13.7001): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 37% Konfidenz.
# - Detektion bei (60.2675, 24.9031): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 39% Konfidenz.
# - Detektion bei (56.1845, 15.6738): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (54.0862, 12.1178): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 79% Konfidenz.
# - Detektion bei (53.8431, 11.4990): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 68% Konfidenz.
# - Detektion bei (54.3340, 18.5849): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 99% Konfidenz.
# - Detektion bei (56.1141, 15.5960): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 41% Konfidenz.
# - Detektion bei (59.3270, 18.0680): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 69% Konfidenz.
# - Detektion bei (54.4410, 18.5423): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 66% Konfidenz.
# - Detektion bei (59.3556, 24.0667): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 33% Konfidenz.
# - Detektion bei (56.0907, 15.6453): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 98% Konfidenz.
# - Detektion bei (54.3763, 10.0633): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 82% Konfidenz.
# - Detektion bei (60.2220, 24.9770): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 52% Konfidenz.
# - Detektion bei (56.2269, 15.6090): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 64% Konfidenz.
# - Detektion bei (54.1485, 12.0796): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 56% Konfidenz.
# - Detektion bei (60.4749, 22.2016): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 59% Konfidenz.
# - Detektion bei (59.5350, 24.7483): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 37% Konfidenz.
# - Detektion bei (54.4419, 13.5785): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 84% Konfidenz.
# - Detektion bei (59.3835, 18.0555): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 85% Konfidenz.
# - Detektion bei (56.1639, 15.6077): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 91% Konfidenz.
# - Detektion bei (55.0705, 14.6775): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 89% Konfidenz.
# - Detektion bei (60.2209, 24.9716): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 46% Konfidenz.
# - Detektion bei (54.2735, 13.1253): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (54.2739, 18.6594): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (59.2719, 17.9690): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 34% Konfidenz.
# - Detektion bei (54.2727, 10.2131): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 75% Konfidenz.
# - Detektion bei (56.2505, 15.5662): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 67% Konfidenz.
# - Detektion bei (60.5148, 22.2879): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 57% Konfidenz.
# - Detektion bei (56.9081, 24.0789): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 44% Konfidenz.
# - Detektion bei (54.6397, 16.9443): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 96% Konfidenz.
# - Detektion bei (54.3158, 10.1616): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (55.7499, 21.1690): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 59% Konfidenz.
# - Detektion bei (54.4038, 10.0502): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 89% Konfidenz.
# - Detektion bei (54.0002, 12.2339): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 96% Konfidenz.
# - Detektion bei (57.4309, 21.5408): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (55.1167, 14.7520): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (59.3498, 24.7460): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 37% Konfidenz.
# - Detektion bei (53.9735, 11.3888): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (60.5280, 22.3208): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (54.3390, 10.1761): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 94% Konfidenz.
# - Detektion bei (54.5339, 18.6135): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 55% Konfidenz.
# - Detektion bei (54.5382, 13.7125): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 95% Konfidenz.
# - Detektion bei (53.9977, 14.2173): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 58% Konfidenz.
# - Detektion bei (54.5548, 16.8476): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 96% Konfidenz.
# - Detektion bei (59.3132, 18.0687): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 97% Konfidenz.
# - Detektion bei (54.5000, 13.5952): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 59% Konfidenz.
# - Detektion bei (53.7954, 11.3653): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 56% Konfidenz.
# - Detektion bei (54.2738, 10.1953): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 44% Konfidenz.
# - Detektion bei (57.3898, 21.5237): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 80% Konfidenz.
# - Detektion bei (54.1097, 12.1077): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 57% Konfidenz.
# - Detektion bei (59.2747, 17.9693): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 58% Konfidenz.
# - Detektion bei (54.0380, 12.1187): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 99% Konfidenz.
# - Detektion bei (53.8932, 11.5191): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (55.0285, 14.7845): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 93% Konfidenz.
# - Detektion bei (56.8542, 24.1659): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 85% Konfidenz.
# - Detektion bei (59.3754, 18.0696): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 96% Konfidenz.
# - Detektion bei (54.4230, 18.5871): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 32% Konfidenz.
# - Detektion bei (59.2719, 18.0264): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (54.4803, 18.5207): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 41% Konfidenz.
# - Detektion bei (54.2754, 18.6318): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 59% Konfidenz.
# - Detektion bei (59.3701, 24.0245): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 93% Konfidenz.
# - Detektion bei (59.3360, 18.1565): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (53.8386, 11.4128): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 56% Konfidenz.
# - Detektion bei (53.9808, 14.3407): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 90% Konfidenz.
# - Detektion bei (53.9706, 14.2452): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 65% Konfidenz.
# - Detektion bei (56.5351, 21.0904): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 96% Konfidenz.
# - Detektion bei (57.4632, 21.6049): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 44% Konfidenz.
# - Detektion bei (56.1406, 15.5861): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 50% Konfidenz.
# - Detektion bei (54.3662, 10.0874): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 83% Konfidenz.
# - Detektion bei (55.6608, 21.1424): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (54.4125, 18.6509): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 82% Konfidenz.
# - Detektion bei (54.2568, 13.1612): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 44% Konfidenz.
# - Detektion bei (53.8350, 11.3862): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 60% Konfidenz.
# - Detektion bei (54.5338, 13.7077): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 54% Konfidenz.
# - Detektion bei (56.2216, 15.5184): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 93% Konfidenz.
# - Detektion bei (53.8046, 11.4263): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 65% Konfidenz.
# - Detektion bei (60.5252, 22.2586): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 56% Konfidenz.
# - Detektion bei (54.4836, 16.8340): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (56.4660, 20.9861): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 93% Konfidenz.
# - Detektion bei (55.6496, 21.0965): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 80% Konfidenz.
# - Detektion bei (56.5794, 20.9948): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 95% Konfidenz.
# - Detektion bei (56.4768, 20.9781): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 80% Konfidenz.
# - Detektion bei (56.5361, 20.9814): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 57% Konfidenz.
# - Detektion bei (56.4894, 20.9565): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 84% Konfidenz.
# - Detektion bei (54.4422, 18.6481): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 56% Konfidenz.
# - Detektion bei (59.4529, 24.0251): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 50% Konfidenz.
# - Detektion bei (56.8898, 24.0843): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 99% Konfidenz.
# - Detektion bei (54.2619, 10.1769): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 57% Konfidenz.
# - Detektion bei (59.5283, 24.8041): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 75% Konfidenz.
# - Detektion bei (55.1887, 14.6758): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (56.1670, 15.5849): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (57.3959, 21.5140): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (59.3700, 18.1631): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 83% Konfidenz.
# - Detektion bei (55.1991, 14.6214): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 89% Konfidenz.
# - Detektion bei (60.2641, 24.9598): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 87% Konfidenz.
# - Detektion bei (56.9077, 24.1129): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 95% Konfidenz.
# - Detektion bei (54.3562, 10.0767): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 36% Konfidenz.
# - Detektion bei (59.4071, 18.1483): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 85% Konfidenz.
# - Detektion bei (60.4464, 22.2336): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 89% Konfidenz.
# - Detektion bei (54.3215, 18.6633): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 66% Konfidenz.
# - Detektion bei (56.1515, 15.6422): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 87% Konfidenz.
# - Detektion bei (54.5737, 18.5842): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 88% Konfidenz.
# - Detektion bei (55.1268, 14.7474): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 49% Konfidenz.
# - Detektion bei (54.0323, 12.1848): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 94% Konfidenz.
# - Detektion bei (54.6264, 16.9368): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 67% Konfidenz.
# - Detektion bei (55.0273, 14.6066): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 86% Konfidenz.
# - Detektion bei (59.4495, 24.6757): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (54.4906, 16.8039): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 99% Konfidenz.
# - Detektion bei (59.2720, 24.1032): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 92% Konfidenz.
# - Detektion bei (57.4606, 21.4908): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 56% Konfidenz.
# - Detektion bei (54.4949, 13.6638): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 97% Konfidenz.
# - Detektion bei (54.3510, 10.1025): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 64% Konfidenz.
# - Detektion bei (54.4194, 18.5723): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 68% Konfidenz.
# - Detektion bei (54.3457, 18.6725): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 58% Konfidenz.
# - Detektion bei (55.1855, 14.6581): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 82% Konfidenz.
# - Detektion bei (54.3001, 18.5593): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 42% Konfidenz.
# - Detektion bei (54.4115, 18.6613): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 55% Konfidenz.
# - Detektion bei (59.2375, 18.1368): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 64% Konfidenz.
# - Detektion bei (57.2908, 21.5572): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 56% Konfidenz.
# - Detektion bei (59.3857, 24.0396): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 46% Konfidenz.
# - Detektion bei (60.3843, 22.3641): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 42% Konfidenz.
# - Detektion bei (57.3096, 21.6376): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 67% Konfidenz.
# - Detektion bei (57.0093, 24.1211): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 81% Konfidenz.
# - Detektion bei (54.3058, 10.0747): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (54.5084, 18.5575): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 56% Konfidenz.
# - Detektion bei (59.3377, 24.0418): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 87% Konfidenz.
# - Detektion bei (60.2565, 24.9217): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 55% Konfidenz.
# - Detektion bei (54.5720, 13.5905): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 57% Konfidenz.
# - Detektion bei (54.5688, 13.6654): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 99% Konfidenz.
# - Detektion bei (53.9317, 11.4476): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 43% Konfidenz.
# - Detektion bei (57.4352, 21.4870): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (59.3601, 18.1524): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 99% Konfidenz.
# - Detektion bei (55.6489, 21.0768): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 96% Konfidenz.
# - Detektion bei (56.9496, 24.1944): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 79% Konfidenz.
# - Detektion bei (54.1762, 12.0442): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (56.2487, 15.6030): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 60% Konfidenz.
# - Detektion bei (59.4763, 24.7996): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 93% Konfidenz.
# - Detektion bei (55.0890, 14.6993): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 64% Konfidenz.
# - Detektion bei (59.3731, 18.0170): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 36% Konfidenz.
# - Detektion bei (54.4800, 13.6621): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (56.8688, 24.1771): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 56% Konfidenz.
# - Detektion bei (59.3406, 24.0567): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (56.4189, 21.0265): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 33% Konfidenz.
# - Detektion bei (56.1959, 15.6277): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 94% Konfidenz.
# - Detektion bei (60.0866, 24.9622): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 53% Konfidenz.
# - Detektion bei (54.2916, 10.1150): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 68% Konfidenz.
# - Detektion bei (54.2381, 13.1187): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 94% Konfidenz.
# - Detektion bei (53.8908, 11.4429): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 92% Konfidenz.
# - Detektion bei (60.3872, 22.2711): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 96% Konfidenz.
# - Detektion bei (59.4393, 24.0584): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (54.4364, 18.6971): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 50% Konfidenz.
# - Detektion bei (54.5598, 13.6969): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 40% Konfidenz.
# - Detektion bei (54.5719, 13.6923): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 63% Konfidenz.
# - Detektion bei (59.3068, 24.1090): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 53% Konfidenz.
# - Detektion bei (60.2528, 25.0103): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 99% Konfidenz.
# - Detektion bei (54.0077, 12.1496): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 51% Konfidenz.
# - Detektion bei (53.9870, 11.4115): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 96% Konfidenz.
# - Detektion bei (60.1858, 24.9708): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 99% Konfidenz.
# - Detektion bei (56.9271, 24.0495): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 63% Konfidenz.
# - Detektion bei (60.0891, 24.9811): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 89% Konfidenz.
# - Detektion bei (54.5606, 18.5645): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (59.3982, 18.1087): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 96% Konfidenz.
# - Detektion bei (54.5325, 16.8091): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 54% Konfidenz.
# - Detektion bei (59.4162, 24.1182): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 97% Konfidenz.
# - Detektion bei (54.4594, 13.5522): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 58% Konfidenz.
# - Detektion bei (54.4543, 13.6656): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 86% Konfidenz.
# - Detektion bei (59.3018, 23.9678): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 98% Konfidenz.
# - Detektion bei (56.9666, 24.1471): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 70% Konfidenz.
# - Detektion bei (59.3840, 18.1126): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 94% Konfidenz.
# - Detektion bei (53.9941, 14.3230): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (54.5525, 18.5228): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 47% Konfidenz.
# - Detektion bei (59.2999, 24.1379): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 51% Konfidenz.
# - Detektion bei (54.6715, 16.9205): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (56.9956, 24.1177): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 54% Konfidenz.
# - Detektion bei (55.1221, 14.8019): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 96% Konfidenz.
# - Detektion bei (60.1738, 24.9030): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (60.1163, 24.9636): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 67% Konfidenz.
# - Detektion bei (54.2237, 10.0551): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 59% Konfidenz.
# - Detektion bei (54.5830, 16.9444): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (55.6448, 21.1219): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 61% Konfidenz.
# - Detektion bei (56.8957, 24.2004): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 49% Konfidenz.
# - Detektion bei (53.9740, 14.3159): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 83% Konfidenz.
# - Detektion bei (60.2678, 24.8401): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 39% Konfidenz.
# - Detektion bei (59.3588, 23.9871): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 54% Konfidenz.
# - Detektion bei (54.4437, 18.5653): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 95% Konfidenz.
# - Detektion bei (60.2474, 24.9994): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 85% Konfidenz.
# - Detektion bei (55.0058, 14.7342): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 78% Konfidenz.
# - Detektion bei (59.5139, 24.6997): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 38% Konfidenz.
# - Detektion bei (59.3156, 24.0594): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 98% Konfidenz.
# - Detektion bei (57.2929, 21.6244): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 89% Konfidenz.
# - Detektion bei (54.4277, 13.7385): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 89% Konfidenz.
# - Detektion bei (57.4618, 21.6021): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 55% Konfidenz.
# - Detektion bei (54.6507, 16.9539): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 87% Konfidenz.
# - Detektion bei (54.0496, 12.0573): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 89% Konfidenz.
# - Detektion bei (56.8677, 24.1989): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 86% Konfidenz.
# - Detektion bei (59.3693, 24.8012): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 60% Konfidenz.
# - Detektion bei (54.4385, 18.6083): Typ 'SUBMARINE', Klassifizierung 'POSSIBLE_SUBMARINE' mit 67% Konfidenz.
# - Detektion bei (54.1034, 12.1573): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 88% Konfidenz.
# - Detektion bei (57.3413, 21.4930): Typ 'ORDNANCE', Klassifizierung 'POSSIBLE_TORPEDO' mit 47% Konfidenz.
# - Detektion bei (54.2660, 18.7261): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 92% Konfidenz.
# - Detektion bei (55.7738, 21.0463): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (54.3421, 13.0605): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 98% Konfidenz.
# - Detektion bei (59.4633, 24.7264): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 97% Konfidenz.
# - Detektion bei (56.4982, 21.0698): Typ 'SUBMARINE', Klassifizierung 'MIDGET_SUBMARINE' mit 79% Konfidenz.
# - Detektion bei (54.0619, 12.0873): Typ 'SUBMARINE', Klassifizierung 'CONFIRMED_SUBMARINE' mit 96% Konfidenz.
# - Detektion bei (53.8220, 11.4392): Typ 'SUBMARINE', Klassifizierung 'LARGE_DIESEL_ELECTRIC' mit 95% Konfidenz.
#
# 7. UNTERWASSERLAGE: DETEKTIONEN IN HAFENNÄHE
# ------------------------------------------------
# - Boje MAD-1826 meldet Objekt 'ORDNANCE' 4.34 km von Hafen Gdynia.
# - Boje MAD-1825 meldet Objekt 'NATURAL_PHENOMENON' 7.17 km von Hafen Karlskrona.
# - Boje MAD-1824 meldet Objekt 'SUBMARINE' 6.82 km von Hafen Stockholm.
# - Boje MAD-1823 meldet Objekt 'ORDNANCE' 8.78 km von Hafen Gdańsk.
# - Boje MAD-1822 meldet Objekt 'SUBMARINE' 5.13 km von Hafen Stockholm.
# - Boje MAD-1821 meldet Objekt 'NATURAL_PHENOMENON' 6.04 km von Hafen Kiel.
# - Boje MAD-1819 meldet Objekt 'BIOLOGICAL' 7.13 km von Hafen Turku.
# - Boje MAD-1817 meldet Objekt 'MANMADE_STRUCTURE' 5.23 km von Hafen Ventspils.
# - Boje MAD-1815 meldet Objekt 'SUBMARINE' 9.73 km von Hafen Rønne.
# - Boje MAD-1813 meldet Objekt 'NATURAL_PHENOMENON' 6.90 km von Hafen Karlskrona.
# - Boje MAD-1812 meldet Objekt 'SURFACE_VESSEL' 4.28 km von Hafen Ustka.
# - Boje MAD-1811 meldet Objekt 'SUBMARINE' 8.24 km von Hafen Gdynia.
# - Boje MAD-1809 meldet Objekt 'BIOLOGICAL' 4.23 km von Hafen Kiel.
# - Boje MAD-1808 meldet Objekt 'ORDNANCE' 9.01 km von Hafen Paldiski.
# - Boje MAD-1807 meldet Objekt 'SUBMARINE' 8.38 km von Hafen Karlskrona.
# - Boje MAD-1805 meldet Objekt 'SUBMARINE' 1.18 km von Hafen Gdynia.
# - Boje MAD-1803 meldet Objekt 'SUBMARINE' 5.31 km von Hafen Stralsund.
# - Boje MAD-1802 meldet Objekt 'SUBMARINE' 0.65 km von Hafen Stockholm.
# - Boje MAD-1801 meldet Objekt 'SUBMARINE' 2.99 km von Hafen Ventspils.
# - Boje MAD-1800 meldet Objekt 'SUBMARINE' 3.59 km von Hafen Ventspils.
# - Boje MAD-1798 meldet Objekt 'MANMADE_STRUCTURE' 7.58 km von Hafen Klaipėda.
# - Boje MAD-1797 meldet Objekt 'MANMADE_STRUCTURE' 7.41 km von Hafen Sassnitz.
# - Boje MAD-1796 meldet Objekt 'SUBMARINE' 1.70 km von Hafen Rønne.
# - Boje MAD-1794 meldet Objekt 'SUBMARINE' 5.08 km von Hafen Tallinn.
# - Boje MAD-1793 meldet Objekt 'SUBMARINE' 9.78 km von Hafen Karlskrona.
# - Boje MAD-1791 meldet Objekt 'MANMADE_STRUCTURE' 4.54 km von Hafen Kiel.
# - Boje MAD-1790 meldet Objekt 'SUBMARINE' 5.41 km von Hafen Riga.
# - Boje MAD-1789 meldet Objekt 'NATURAL_PHENOMENON' 5.98 km von Hafen Gdynia.
# - Boje MAD-1788 meldet Objekt 'MANMADE_STRUCTURE' 8.58 km von Hafen Paldiski.
# - Boje MAD-1787 meldet Objekt 'BIOLOGICAL' 9.97 km von Hafen Paldiski.
# - Boje MAD-1786 meldet Objekt 'SUBMARINE' 7.38 km von Hafen Klaipėda.
# - Boje MAD-1784 meldet Objekt 'SUBMARINE' 5.86 km von Hafen Stockholm.
# - Boje MAD-1783 meldet Objekt 'GEOLOGICAL' 5.00 km von Hafen Paldiski.
# - Boje MAD-1782 meldet Objekt 'SUBMARINE' 6.78 km von Hafen Ventspils.
# - Boje MAD-1781 meldet Objekt 'GEOLOGICAL' 4.99 km von Hafen Turku.
# - Boje MAD-1779 meldet Objekt 'NATURAL_PHENOMENON' 3.89 km von Hafen Riga.
# - Boje MAD-1779 meldet Objekt 'NATURAL_PHENOMENON' 9.91 km von Hafen Bolderāja.
# - Boje MAD-1778 meldet Objekt 'SUBMARINE' 4.62 km von Hafen Tallinn.
# - Boje MAD-1776 meldet Objekt 'SUBMARINE' 7.16 km von Hafen Ustka.
# - Boje MAD-1775 meldet Objekt 'SUBMARINE' 6.91 km von Hafen Rostock.
# - Boje MAD-1774 meldet Objekt 'BIOLOGICAL' 4.35 km von Hafen Tallinn.
# - Boje MAD-1773 meldet Objekt 'MANMADE_STRUCTURE' 3.18 km von Hafen Rønne.
# ...
# - Boje MAD-243 meldet Objekt 'GEOLOGICAL' 9.94 km von Hafen Gdańsk.
# - Boje MAD-241 meldet Objekt 'SUBMARINE' 5.54 km von Hafen Bolderāja.
# - Boje MAD-240 meldet Objekt 'SUBMARINE' 3.53 km von Hafen Sassnitz.
# - Boje MAD-239 meldet Objekt 'SUBMARINE' 7.98 km von Hafen Rostock.
# - Boje MAD-238 meldet Objekt 'SURFACE_VESSEL' 8.93 km von Hafen Kiel.
# - Boje MAD-237 meldet Objekt 'MANMADE_STRUCTURE' 7.24 km von Hafen Wismar.
# - Boje MAD-236 meldet Objekt 'SUBMARINE' 5.83 km von Hafen Ventspils.
# - Boje MAD-235 meldet Objekt 'SUBMARINE' 9.47 km von Hafen Paldiski.
# - Boje MAD-233 meldet Objekt 'SUBMARINE' 6.87 km von Hafen Kiel.
# - Boje MAD-232 meldet Objekt 'ORDNANCE' 4.66 km von Hafen Klaipėda.
# - Boje MAD-231 meldet Objekt 'BIOLOGICAL' 6.94 km von Hafen Stockholm.
# - Boje MAD-230 meldet Objekt 'NATURAL_PHENOMENON' 3.92 km von Hafen Sassnitz.
# - Boje MAD-229 meldet Objekt 'SUBMARINE' 5.61 km von Hafen Rostock.
# - Boje MAD-228 meldet Objekt 'SUBMARINE' 8.02 km von Hafen Karlskrona.
# - Boje MAD-227 meldet Objekt 'SUBMARINE' 2.63 km von Hafen Riga.
# - Boje MAD-227 meldet Objekt 'SUBMARINE' 3.65 km von Hafen Bolderāja.
# - Boje MAD-226 meldet Objekt 'SUBMARINE' 7.72 km von Hafen Karlskrona.
# - Boje MAD-225 meldet Objekt 'NATURAL_PHENOMENON' 7.14 km von Hafen Liepāja.
# - Boje MAD-224 meldet Objekt 'MANMADE_STRUCTURE' 7.50 km von Hafen Tallinn.
# - Boje MAD-223 meldet Objekt 'SURFACE_VESSEL' 9.74 km von Hafen Świnoujście.
# - Boje MAD-222 meldet Objekt 'NATURAL_PHENOMENON' 6.85 km von Hafen Liepāja.
# - Boje MAD-221 meldet Objekt 'BIOLOGICAL' 8.95 km von Hafen Kiel.
# - Boje MAD-220 meldet Objekt 'SUBMARINE' 8.37 km von Hafen Rønne.
# - Boje MAD-219 meldet Objekt 'MANMADE_STRUCTURE' 7.77 km von Hafen Liepāja.
# - Boje MAD-218 meldet Objekt 'SUBMARINE' 9.63 km von Hafen Helsinki.
# - Boje MAD-217 meldet Objekt 'MANMADE_STRUCTURE' 9.99 km von Hafen Kiel.
# - Boje MAD-216 meldet Objekt 'ORDNANCE' 9.69 km von Hafen Riga.
# - Boje MAD-216 meldet Objekt 'ORDNANCE' 7.05 km von Hafen Bolderāja.
# - Boje MAD-215 meldet Objekt 'ORDNANCE' 7.17 km von Hafen Turku.
# - Boje MAD-214 meldet Objekt 'SURFACE_VESSEL' 9.86 km von Hafen Karlskrona.
# - Boje MAD-213 meldet Objekt 'MANMADE_STRUCTURE' 7.79 km von Hafen Ustka.
# - Boje MAD-212 meldet Objekt 'MANMADE_STRUCTURE' 5.33 km von Hafen Sassnitz.
# - Boje MAD-211 meldet Objekt 'SUBMARINE' 9.79 km von Hafen Riga.
# - Boje MAD-210 meldet Objekt 'ORDNANCE' 3.45 km von Hafen Tallinn.
# - Boje MAD-209 meldet Objekt 'GEOLOGICAL' 6.26 km von Hafen Stockholm.
# - Boje MAD-208 meldet Objekt 'NATURAL_PHENOMENON' 9.65 km von Hafen Rønne.
# - Boje MAD-206 meldet Objekt 'SUBMARINE' 2.90 km von Hafen Ventspils.
# - Boje MAD-205 meldet Objekt 'SUBMARINE' 3.16 km von Hafen Kiel.
# - Boje MAD-203 meldet Objekt 'BIOLOGICAL' 6.14 km von Hafen Karlskrona.
# - Boje MAD-202 meldet Objekt 'GEOLOGICAL' 4.52 km von Hafen Helsinki.
# - Boje MAD-201 meldet Objekt 'SUBMARINE' 9.31 km von Hafen Rostock.
# - Boje MAD-198 meldet Objekt 'SUBMARINE' 6.20 km von Hafen Rønne.
# - Boje MAD-197 meldet Objekt 'SUBMARINE' 6.03 km von Hafen Tallinn.
# - Boje MAD-196 meldet Objekt 'SUBMARINE' 5.86 km von Hafen Riga.
# - Boje MAD-195 meldet Objekt 'SUBMARINE' 6.54 km von Hafen Riga.
# - Boje MAD-195 meldet Objekt 'SUBMARINE' 1.90 km von Hafen Bolderāja.
# - Boje MAD-194 meldet Objekt 'ORDNANCE' 5.73 km von Hafen Ustka.
# - Boje MAD-192 meldet Objekt 'GEOLOGICAL' 8.09 km von Hafen Tallinn.
# - Boje MAD-191 meldet Objekt 'SUBMARINE' 6.88 km von Hafen Helsinki.
# - Boje MAD-190 meldet Objekt 'ORDNANCE' 1.90 km von Hafen Turku.
# - Boje MAD-189 meldet Objekt 'SUBMARINE' 6.37 km von Hafen Świnoujście.
# - Boje MAD-188 meldet Objekt 'MANMADE_STRUCTURE' 6.99 km von Hafen Rønne.
# - Boje MAD-187 meldet Objekt 'GEOLOGICAL' 1.98 km von Hafen Gdynia.
# - Boje MAD-186 meldet Objekt 'SUBMARINE' 9.97 km von Hafen Sassnitz.
# - Boje MAD-185 meldet Objekt 'GEOLOGICAL' 1.36 km von Hafen Kiel.
# - Boje MAD-184 meldet Objekt 'SUBMARINE' 9.77 km von Hafen Karlskrona.
# - Boje MAD-183 meldet Objekt 'BIOLOGICAL' 2.42 km von Hafen Ustka.
# - Boje MAD-182 meldet Objekt 'SUBMARINE' 6.38 km von Hafen Kiel.
# - Boje MAD-181 meldet Objekt 'BIOLOGICAL' 4.95 km von Hafen Turku.
# - Boje MAD-180 meldet Objekt 'SUBMARINE' 4.98 km von Hafen Rønne.
# - Boje MAD-179 meldet Objekt 'SURFACE_VESSEL' 8.80 km von Hafen Gdynia.
# - Boje MAD-178 meldet Objekt 'NATURAL_PHENOMENON' 6.50 km von Hafen Turku.
# - Boje MAD-176 meldet Objekt 'NATURAL_PHENOMENON' 5.86 km von Hafen Paldiski.
# - Boje MAD-175 meldet Objekt 'ORDNANCE' 9.16 km von Hafen Liepāja.
# - Boje MAD-173 meldet Objekt 'SUBMARINE' 9.04 km von Hafen Ventspils.
# - Boje MAD-171 meldet Objekt 'SUBMARINE' 7.00 km von Hafen Turku.
# - Boje MAD-170 meldet Objekt 'NATURAL_PHENOMENON' 7.46 km von Hafen Stralsund.
# - Boje MAD-169 meldet Objekt 'NATURAL_PHENOMENON' 2.91 km von Hafen Wismar.
# - Boje MAD-168 meldet Objekt 'SUBMARINE' 0.72 km von Hafen Gdynia.
# - Boje MAD-166 meldet Objekt 'SUBMARINE' 5.84 km von Hafen Świnoujście.
# - Boje MAD-165 meldet Objekt 'ORDNANCE' 4.75 km von Hafen Tallinn.
# - Boje MAD-164 meldet Objekt 'GEOLOGICAL' 7.63 km von Hafen Stralsund.
# - Boje MAD-163 meldet Objekt 'SUBMARINE' 9.95 km von Hafen Klaipėda.
# - Boje MAD-162 meldet Objekt 'SUBMARINE' 8.16 km von Hafen Tallinn.
# - Boje MAD-161 meldet Objekt 'SUBMARINE' 9.22 km von Hafen Riga.
# - Boje MAD-161 meldet Objekt 'SUBMARINE' 3.26 km von Hafen Bolderāja.
# - Boje MAD-160 meldet Objekt 'SUBMARINE' 1.31 km von Hafen Tallinn.
# - Boje MAD-159 meldet Objekt 'BIOLOGICAL' 8.10 km von Hafen Klaipėda.
# - Boje MAD-157 meldet Objekt 'SUBMARINE' 7.04 km von Hafen Tallinn.
# - Boje MAD-156 meldet Objekt 'NATURAL_PHENOMENON' 1.64 km von Hafen Gdańsk.
# - Boje MAD-155 meldet Objekt 'SUBMARINE' 5.16 km von Hafen Ustka.
# - Boje MAD-154 meldet Objekt 'NATURAL_PHENOMENON' 7.22 km von Hafen Klaipėda.
# - Boje MAD-153 meldet Objekt 'BIOLOGICAL' 9.50 km von Hafen Ustka.
# - Boje MAD-151 meldet Objekt 'NATURAL_PHENOMENON' 3.89 km von Hafen Liepāja.
# - Boje MAD-150 meldet Objekt 'SURFACE_VESSEL' 6.46 km von Hafen Sassnitz.
# - Boje MAD-148 meldet Objekt 'ORDNANCE' 5.87 km von Hafen Gdańsk.
# - Boje MAD-147 meldet Objekt 'SUBMARINE' 8.32 km von Hafen Rostock.
# - Boje MAD-146 meldet Objekt 'SUBMARINE' 8.23 km von Hafen Świnoujście.
# - Boje MAD-145 meldet Objekt 'GEOLOGICAL' 1.86 km von Hafen Tallinn.
# - Boje MAD-144 meldet Objekt 'BIOLOGICAL' 9.35 km von Hafen Rostock.
# - Boje MAD-143 meldet Objekt 'SUBMARINE' 4.35 km von Hafen Turku.
# - Boje MAD-142 meldet Objekt 'SUBMARINE' 9.78 km von Hafen Riga.
# - Boje MAD-142 meldet Objekt 'SUBMARINE' 3.99 km von Hafen Bolderāja.
# - Boje MAD-141 meldet Objekt 'SUBMARINE' 5.47 km von Hafen Ventspils.
# - Boje MAD-140 meldet Objekt 'SURFACE_VESSEL' 5.98 km von Hafen Turku.
# - Boje MAD-139 meldet Objekt 'MANMADE_STRUCTURE' 6.10 km von Hafen Gdańsk.
# - Boje MAD-138 meldet Objekt 'SUBMARINE' 5.83 km von Hafen Ventspils.
# - Boje MAD-137 meldet Objekt 'BIOLOGICAL' 8.58 km von Hafen Klaipėda.
# - Boje MAD-136 meldet Objekt 'SUBMARINE' 2.96 km von Hafen Turku.
# - Boje MAD-135 meldet Objekt 'SUBMARINE' 5.64 km von Hafen Turku.
# - Boje MAD-134 meldet Objekt 'SUBMARINE' 2.05 km von Hafen Liepāja.
# - Boje MAD-133 meldet Objekt 'SUBMARINE' 3.01 km von Hafen Sassnitz.
# - Boje MAD-132 meldet Objekt 'BIOLOGICAL' 9.82 km von Hafen Riga.
# - Boje MAD-132 meldet Objekt 'BIOLOGICAL' 7.10 km von Hafen Bolderāja.
# - Boje MAD-129 meldet Objekt 'GEOLOGICAL' 4.34 km von Hafen Rønne.
# - Boje MAD-128 meldet Objekt 'ORDNANCE' 7.64 km von Hafen Gdańsk.
# - Boje MAD-127 meldet Objekt 'SUBMARINE' 6.96 km von Hafen Stralsund.
# - Boje MAD-126 meldet Objekt 'SUBMARINE' 5.66 km von Hafen Gdańsk.
# - Boje MAD-125 meldet Objekt 'ORDNANCE' 4.21 km von Hafen Paldiski.
# - Boje MAD-124 meldet Objekt 'SURFACE_VESSEL' 5.77 km von Hafen Ventspils.
# - Boje MAD-123 meldet Objekt 'GEOLOGICAL' 4.10 km von Hafen Riga.
# - Boje MAD-123 meldet Objekt 'GEOLOGICAL' 8.84 km von Hafen Bolderāja.
# - Boje MAD-122 meldet Objekt 'MANMADE_STRUCTURE' 4.60 km von Hafen Rønne.
# - Boje MAD-121 meldet Objekt 'MANMADE_STRUCTURE' 7.30 km von Hafen Karlskrona.
# - Boje MAD-120 meldet Objekt 'MANMADE_STRUCTURE' 7.11 km von Hafen Liepāja.
# - Boje MAD-119 meldet Objekt 'ORDNANCE' 7.57 km von Hafen Karlskrona.
# - Boje MAD-118 meldet Objekt 'BIOLOGICAL' 9.85 km von Hafen Kiel.
# - Boje MAD-117 meldet Objekt 'SURFACE_VESSEL' 3.93 km von Hafen Rostock.
# - Boje MAD-116 meldet Objekt 'ORDNANCE' 7.67 km von Hafen Riga.
# - Boje MAD-116 meldet Objekt 'ORDNANCE' 5.03 km von Hafen Bolderāja.
# - Boje MAD-115 meldet Objekt 'MANMADE_STRUCTURE' 6.13 km von Hafen Sassnitz.
# - Boje MAD-114 meldet Objekt 'MANMADE_STRUCTURE' 8.15 km von Hafen Sassnitz.
# - Boje MAD-113 meldet Objekt 'BIOLOGICAL' 4.15 km von Hafen Helsinki.
# - Boje MAD-112 meldet Objekt 'GEOLOGICAL' 9.18 km von Hafen Gdynia.
# - Boje MAD-110 meldet Objekt 'ORDNANCE' 9.00 km von Hafen Kiel.
# - Boje MAD-109 meldet Objekt 'GEOLOGICAL' 7.76 km von Hafen Ventspils.
# - Boje MAD-108 meldet Objekt 'ORDNANCE' 9.85 km von Hafen Sassnitz.
# - Boje MAD-107 meldet Objekt 'BIOLOGICAL' 8.48 km von Hafen Liepāja.
# - Boje MAD-106 meldet Objekt 'GEOLOGICAL' 3.97 km von Hafen Rønne.
# - Boje MAD-105 meldet Objekt 'NATURAL_PHENOMENON' 9.00 km von Hafen Riga.
# - Boje MAD-105 meldet Objekt 'NATURAL_PHENOMENON' 3.93 km von Hafen Bolderāja.
# - Boje MAD-104 meldet Objekt 'BIOLOGICAL' 7.10 km von Hafen Sassnitz.
# - Boje MAD-103 meldet Objekt 'BIOLOGICAL' 5.24 km von Hafen Turku.
# - Boje MAD-102 meldet Objekt 'GEOLOGICAL' 6.11 km von Hafen Kiel.
# - Boje MAD-101 meldet Objekt 'ORDNANCE' 9.82 km von Hafen Liepāja.
# - Boje MAD-100 meldet Objekt 'SURFACE_VESSEL' 5.46 km von Hafen Rønne.
# - Boje MAD-99 meldet Objekt 'SUBMARINE' 4.29 km von Hafen Karlskrona.
# - Boje MAD-98 meldet Objekt 'MANMADE_STRUCTURE' 7.76 km von Hafen Stockholm.
# - Boje MAD-97 meldet Objekt 'BIOLOGICAL' 3.78 km von Hafen Riga.
# - Boje MAD-97 meldet Objekt 'BIOLOGICAL' 8.37 km von Hafen Bolderāja.
# - Boje MAD-96 meldet Objekt 'SUBMARINE' 6.58 km von Hafen Rønne.
# - Boje MAD-93 meldet Objekt 'SUBMARINE' 6.80 km von Hafen Świnoujście.
# - Boje MAD-91 meldet Objekt 'MANMADE_STRUCTURE' 8.01 km von Hafen Ventspils.
# - Boje MAD-90 meldet Objekt 'SUBMARINE' 9.62 km von Hafen Stockholm.
# - Boje MAD-89 meldet Objekt 'MANMADE_STRUCTURE' 9.75 km von Hafen Rønne.
# - Boje MAD-88 meldet Objekt 'SUBMARINE' 6.13 km von Hafen Rostock.
# - Boje MAD-87 meldet Objekt 'SUBMARINE' 5.70 km von Hafen Turku.
# - Boje MAD-86 meldet Objekt 'ORDNANCE' 3.82 km von Hafen Helsinki.
# - Boje MAD-85 meldet Objekt 'MANMADE_STRUCTURE' 6.15 km von Hafen Kiel.
# - Boje MAD-84 meldet Objekt 'SUBMARINE' 7.02 km von Hafen Karlskrona.
# - Boje MAD-83 meldet Objekt 'SUBMARINE' 9.86 km von Hafen Sassnitz.
# - Boje MAD-81 meldet Objekt 'GEOLOGICAL' 9.06 km von Hafen Wismar.
# - Boje MAD-78 meldet Objekt 'ORDNANCE' 2.73 km von Hafen Sassnitz.
# - Boje MAD-77 meldet Objekt 'BIOLOGICAL' 3.02 km von Hafen Gdynia.
# - Boje MAD-76 meldet Objekt 'MANMADE_STRUCTURE' 7.22 km von Hafen Karlskrona.
# - Boje MAD-75 meldet Objekt 'SURFACE_VESSEL' 7.37 km von Hafen Rostock.
# - Boje MAD-74 meldet Objekt 'SUBMARINE' 3.92 km von Hafen Ventspils.
# - Boje MAD-73 meldet Objekt 'SUBMARINE' 8.56 km von Hafen Gdynia.
# - Boje MAD-72 meldet Objekt 'SUBMARINE' 9.94 km von Hafen Stralsund.
# - Boje MAD-71 meldet Objekt 'SUBMARINE' 7.17 km von Hafen Wismar.
# - Boje MAD-69 meldet Objekt 'BIOLOGICAL' 5.78 km von Hafen Rønne.
# - Boje MAD-68 meldet Objekt 'GEOLOGICAL' 7.30 km von Hafen Świnoujście.
# - Boje MAD-66 meldet Objekt 'NATURAL_PHENOMENON' 6.26 km von Hafen Helsinki.
# - Boje MAD-65 meldet Objekt 'SUBMARINE' 2.22 km von Hafen Riga.
# - Boje MAD-65 meldet Objekt 'SUBMARINE' 4.42 km von Hafen Bolderāja.
# - Boje MAD-64 meldet Objekt 'SUBMARINE' 8.25 km von Hafen Gdańsk.
# - Boje MAD-63 meldet Objekt 'NATURAL_PHENOMENON' 5.95 km von Hafen Rønne.
# - Boje MAD-62 meldet Objekt 'SURFACE_VESSEL' 3.33 km von Hafen Gdynia.
# - Boje MAD-61 meldet Objekt 'SUBMARINE' 7.25 km von Hafen Turku.
# - Boje MAD-60 meldet Objekt 'MANMADE_STRUCTURE' 4.85 km von Hafen Helsinki.
# - Boje MAD-59 meldet Objekt 'BIOLOGICAL' 7.94 km von Hafen Stralsund.
# - Boje MAD-58 meldet Objekt 'ORDNANCE' 8.25 km von Hafen Wismar.
# - Boje MAD-57 meldet Objekt 'GEOLOGICAL' 3.11 km von Hafen Stockholm.
# - Boje MAD-56 meldet Objekt 'NATURAL_PHENOMENON' 6.19 km von Hafen Stockholm.
# - Boje MAD-55 meldet Objekt 'SUBMARINE' 5.15 km von Hafen Helsinki.
# - Boje MAD-53 meldet Objekt 'SURFACE_VESSEL' 9.40 km von Hafen Paldiski.
# - Boje MAD-52 meldet Objekt 'ORDNANCE' 8.43 km von Hafen Ustka.
# - Boje MAD-51 meldet Objekt 'BIOLOGICAL' 3.93 km von Hafen Tallinn.
# - Boje MAD-50 meldet Objekt 'ORDNANCE' 7.67 km von Hafen Ventspils.
# - Boje MAD-48 meldet Objekt 'GEOLOGICAL' 5.45 km von Hafen Gdynia.
# - Boje MAD-47 meldet Objekt 'MANMADE_STRUCTURE' 7.85 km von Hafen Paldiski.
# - Boje MAD-45 meldet Objekt 'SUBMARINE' 5.88 km von Hafen Ventspils.
# - Boje MAD-44 meldet Objekt 'SUBMARINE' 6.73 km von Hafen Świnoujście.
# - Boje MAD-43 meldet Objekt 'ORDNANCE' 4.58 km von Hafen Bolderāja.
# - Boje MAD-42 meldet Objekt 'MANMADE_STRUCTURE' 5.02 km von Hafen Bolderāja.
# - Boje MAD-40 meldet Objekt 'ORDNANCE' 4.60 km von Hafen Ventspils.
# - Boje MAD-39 meldet Objekt 'SURFACE_VESSEL' 6.76 km von Hafen Klaipėda.
# - Boje MAD-38 meldet Objekt 'SUBMARINE' 7.73 km von Hafen Kiel.
# - Boje MAD-36 meldet Objekt 'ORDNANCE' 7.96 km von Hafen Karlskrona.
# - Boje MAD-35 meldet Objekt 'MANMADE_STRUCTURE' 8.70 km von Hafen Świnoujście.
# - Boje MAD-34 meldet Objekt 'MANMADE_STRUCTURE' 6.30 km von Hafen Helsinki.
# - Boje MAD-33 meldet Objekt 'GEOLOGICAL' 6.63 km von Hafen Liepāja.
# - Boje MAD-32 meldet Objekt 'ORDNANCE' 8.93 km von Hafen Świnoujście.
# - Boje MAD-31 meldet Objekt 'SURFACE_VESSEL' 3.36 km von Hafen Liepāja.
# - Boje MAD-30 meldet Objekt 'SUBMARINE' 3.84 km von Hafen Rostock.
# - Boje MAD-29 meldet Objekt 'SUBMARINE' 4.84 km von Hafen Karlskrona.
# - Boje MAD-28 meldet Objekt 'BIOLOGICAL' 2.50 km von Hafen Świnoujście.
# - Boje MAD-26 meldet Objekt 'SUBMARINE' 7.41 km von Hafen Rostock.
# - Boje MAD-25 meldet Objekt 'MANMADE_STRUCTURE' 5.10 km von Hafen Tallinn.
# - Boje MAD-24 meldet Objekt 'SUBMARINE' 2.88 km von Hafen Ventspils.
# - Boje MAD-23 meldet Objekt 'SUBMARINE' 4.45 km von Hafen Helsinki.
# - Boje MAD-22 meldet Objekt 'SUBMARINE' 8.46 km von Hafen Wismar.
# - Boje MAD-21 meldet Objekt 'SURFACE_VESSEL' 2.61 km von Hafen Świnoujście.
# - Boje MAD-20 meldet Objekt 'SUBMARINE' 6.83 km von Hafen Stralsund.
# - Boje MAD-19 meldet Objekt 'SUBMARINE' 5.66 km von Hafen Wismar.
# - Boje MAD-18 meldet Objekt 'SUBMARINE' 9.81 km von Hafen Gdynia.
# - Boje MAD-16 meldet Objekt 'SUBMARINE' 8.50 km von Hafen Rostock.
# - Boje MAD-15 meldet Objekt 'GEOLOGICAL' 8.01 km von Hafen Stockholm.
# - Boje MAD-14 meldet Objekt 'SUBMARINE' 7.86 km von Hafen Kiel.
# - Boje MAD-13 meldet Objekt 'SURFACE_VESSEL' 8.95 km von Hafen Tallinn.
# - Boje MAD-12 meldet Objekt 'MANMADE_STRUCTURE' 4.17 km von Hafen Wismar.
# - Boje MAD-11 meldet Objekt 'MANMADE_STRUCTURE' 9.53 km von Hafen Świnoujście.
# - Boje MAD-10 meldet Objekt 'SUBMARINE' 3.86 km von Hafen Stockholm.
# - Boje MAD-09 meldet Objekt 'SUBMARINE' 1.47 km von Hafen Turku.
# - Boje MAD-08 meldet Objekt 'SUBMARINE' 6.18 km von Hafen Ventspils.
# - Boje MAD-07 meldet Objekt 'SUBMARINE' 9.67 km von Hafen Klaipėda.
# - Boje MAD-04 meldet Objekt 'MANMADE_STRUCTURE' 2.98 km von Hafen Wismar.
# - Boje MAD-03 meldet Objekt 'MANMADE_STRUCTURE' 0.74 km von Hafen Paldiski.
# - Boje MAD-02 meldet Objekt 'SUBMARINE' 7.88 km von Hafen Gdynia.
# - Boje MAD-01 meldet Objekt 'SUBMARINE' 6.74 km von Hafen Karlskrona.
#
# 8. SOCIAL MEDIA INTELLIGENCE (OSINT)
# --------------------------------------
# - Tweet (Priorität: MITTEL) von @heather21: "Explain mouth suddenly painting several film wall bar law image issue. #suspect #sanctioned #Militär 🎖️"
# - Tweet (Priorität: MITTEL) von @benjamin16: "Person Democrat sport control while into box have speech single none girl stay community have reveal TV however machine. #uboot ⚓"
# - Tweet (Priorität: MITTEL) von @patriciamcdaniel: "Leader oil consumer material. #NATO #Marine #suspect 🎖️ 🪖"
#
# ==================== ENDE DES BERICHTS ====================
#
# Spark-Session beendet.
